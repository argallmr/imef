# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from matplotlib.patches import Circle
from matplotlib.patches import Wedge
from mpl_toolkits.mplot3d import Axes3D
import time
import warnings
from bfields import *
from efields import *
from plottools import *
from boris import *
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

# colorscales for color consistency 
seq_standard = 'YlGnBu'
div_standard = 'RdGy'
#pcolor = 'GnBu'

# UNH logo hexcode
nh_blue = '#233E8A'
white = ['#FFFFFF']

# UNH-themed sequential colors
nh_blues = ['#152451', '#233E8A', '#3B62CE','#7C97DE','#BDCBEF','#DFE5F7','#EFF2FB']
nh_grays = ['#333333', '#575757', '#858585','#ADADAD','#D6D6D6','#EBEBEB','#F5F5F5']
nh_blues_r = nh_blues[::-1]
nh_grays_r = nh_grays[::-1]

# UNH-themed divergent colors
nh_cscale = nh_blues+white+nh_grays_r
nh_cscale_r = nh_cscale[::-1] 

nh_cmap_div = LinearSegmentedColormap.from_list('cdiv',nh_cscale,N=500)
nh_cmap_div_r = LinearSegmentedColormap.from_list('cdiv_r',nh_cscale_r,N=500)
nh_cmap_seq = LinearSegmentedColormap.from_list('cseq',nh_blues,N=500)
nh_cmap_seq_r = LinearSegmentedColormap.from_list('cseq_r',nh_blues_r,N=500)

# colorscale for sequential plots
cseq = nh_cmap_seq
cseq_r = nh_cmap_seq_r
# colorscale for divergent plots (negative and positive values)
cdiv = nh_cmap_div

# plot font
#from matplotlib import rc
#rc('font', **{'family': 'serif', 'serif': ['Computer Modern']})
#rc('text', usetex=True)

# %%
'''

constants

''' 
gs = 2.0            # shielding constant
RE = 6371000        # radius of earth [m]
mp = 1.6e-27        # proton mass [kg]
me = 9.1e-31        # electron mass [kg]
qe = 1.603E-19      # proton charge [C]

# kp index
kp = 8.5  
          
# mass of oxygen atom
mo = 2.656e-26 # [kg]

# given angles
theta1 = 2
phi1 = np.radians(69)

# energy
en = 40 # [keV]
en = en*1000 # [eV]
en = en*1.602176e-19 # [J] 

# velcoity magnitude
vmag = np.sqrt(2*en*(1/mo))


# velcoity components
vx = vmag*np.sin(theta1)*np.cos(phi1)
vy = vmag*np.sin(theta1)*np.sin(phi1)
vz = vmag*np.cos(theta1)

nhr = 1+2/3
dt = 0.05
tf = nhr*3600

# creating charged particle
m = 4.*mp
q = 2.*qe


# set initial conditions                            
#r0 = np.array([4.3, -2., 2.])*RE 
#v0 = np.array([vx , vy, vz])

r0 = np.array([1., -7.85, -1.53])*RE
v0 = np.array([0.,.3,.3])

# %%
print('tdat, tdrift,  vdat, rdat, emag = b.boris(tf={0:0d},'
                                                'r0=[{1:0.4f}, {2:0.4f}, {3:0.4f}],'
                                                'v0=[{4:0.4f}, {5:0.4f}, {6:0.4f}],'
                                                'm={7:0.4e},'
                                                'q={8:0.4e},'
                                                'gs={9:1.2f},'
                                                'kp={10:2.1f}, tdir="bw")'
      .format(tf, *r0, *v0, m, q, gs, kp))
# Out:
# tdat, tdrift,  vdat, rdat, emag = b.boris(tf=720000,r0=[6371000.0000, -50012350.0000, -9747630.0000],v0=[0.0000, 0.3000, 0.3000],m=6.4000e-27,q=3.2060e-19,gs=2.00,kp=8.5, tdir="bw")

# %%
import importlib as imp
import boris
imp.reload(boris)
from boris import *

# %%
# compute boris
tdat, tdrift, vdat, rdat, emag = boris(tf, r0, v0, m, q, gs, kp, tdir="fw")
# Out:
# 211570

# %%
vmag = np.sqrt(np.sum(vdat**2, axis=1))
itdat = np.where(tdat > 0)[0]
plt.plot(tdat[itdat], vmag[:-1][itdat])
plt.xlabel('tdat')
plt.ylabel('|vdat|')
# Out:
# Text(0, 0.5, '|vdat|')

# %%
# convert spherical position coordinates to cartesian
# rdat_crt = np.zeros((len(rdat), 3))
# for i, val in enumerate(rdat):
#     x,y,z = sph_to_crt(val[0], val[1], val[2])
#     rdat_crt[i] = np.array([x,y,z])


# scale coordinates in units [RE]  
rscale = rdat/RE

tracingplot_3d(rdat*RE, savefig=False)
tracingplot_2d(rdat*RE, savefig=False)


# diagnostic data
print(f'* drift time: {tdrift} hrs')
print(f'* Initial position: {rscale[0][0], rscale[0][1], rscale[0][2]} RE')
print(f'* Initial velocity: {vdat[0][0], vdat[0][1], vdat[0][2]} m/s')
print(f'* Duration: {tf} s ({round(tf/60,2)} min.) ({round((tf/60)/60,2)} hr.)')
print(f'* E-field: {np.mean(emag):.2e} mV/m (mean), {max(emag):.2e} mV/m (max), {min(emag):.2e} mV/m (min) ')

plt.show()
# Out:
# /Users/argall/Documents/Python/imef/particle-tracing/boris-tracing/plottools.py:377: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax[0].set_xticks(ticks, [abs(i) for i in ticks])
# /Users/argall/Documents/Python/imef/particle-tracing/boris-tracing/plottools.py:378: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax[0].set_yticks(ticks, [abs(i) for i in ticks])
# /Users/argall/Documents/Python/imef/particle-tracing/boris-tracing/plottools.py:379: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax[1].set_xticks(ticks, [abs(i) for i in ticks])
# /Users/argall/Documents/Python/imef/particle-tracing/boris-tracing/plottools.py:380: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax[1].set_yticks(ticks, [abs(i) for i in ticks])
# /Users/argall/Documents/Python/imef/particle-tracing/boris-tracing/plottools.py:381: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax[2].set_xticks(ticks, [abs(i) for i in ticks])
# /Users/argall/Documents/Python/imef/particle-tracing/boris-tracing/plottools.py:382: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax[2].set_yticks(ticks, [abs(i) for i in ticks])
# * drift time: nan hrs
# * Initial position: (1.5696123057604772e-07, -1.2321456600219744e-06, -2.4015068278135304e-07) RE
# * Initial velocity: (0.0, 0.3, 0.3) m/s
# * Duration: 5999.999999999999 s (100.0 min.) (1.67 hr.)
# * E-field: 0.00e+00 mV/m (mean), 0.00e+00 mV/m (max), 0.00e+00 mV/m (min)

# %%
rdat
# Out:
# array([[ 1.        , -7.85      , -1.53      ],
#        [ 1.00014785, -7.8469891 , -1.52701459],
#        [ 1.00044347, -7.84397068, -1.52404782],
#        ...,
#        [-2.76524411,  8.24897047, -2.95899677],
#        [-2.76752741,  8.24855088, -2.9626479 ],
#        [-2.76977655,  8.24817822, -2.96632523]])
